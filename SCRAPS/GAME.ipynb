# %%
# TRAIN GAME V1 (OLD)

import random
import time
import numpy as np

class TrainGameEnv:
    def __init__(self, initial_capacity=100, seed=None, verbose=False):
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)

        # train state
        self.initial_capacity = initial_capacity
        self.capacity = initial_capacity
        self.passengers_onboard = 0

        # scoring trackers
        self.raw_score = 0.0
        self.total_boarded = 0
        self.total_unused = 0.0
        self.total_config_cost = 0.0

        # stations (LRT-2)
        self.stations = [
            "Recto", "Legarda", "Pureza", "V. Mapa", "J. Ruiz", "Gilmore",
            "Betty Go", "Cubao", "Anonas", "Katipunan",
            "Santolan", "Marikina", "Antipolo"
        ]
        self.num_stations = len(self.stations)
        self.station_idx = 0
        self.direction = +1

        # collapse mechanic
        self.weight_window = []
        self.window_size = 10
        self.base_collapse_threshold = 10.0

        # time + progression
        self.sim_hour = random.randint(0, 23)
        self.steps = 0
        self.max_steps = 2000
        self.station_visits = 0

        self.done = False
        self.done_reason = None
        self.verbose = verbose

    # ----------------- helpers -----------------
    def _time_multiplier(self, hour):
        if 6 <= hour <= 8:   # morning rush
            return 1.9
        if 11 <= hour <= 13: # lunch rush
            return 1.6
        if 17 <= hour <= 19: # evening rush
            return 1.9
        return 0.8 if random.random() < 0.45 else 1.0

    def _arrival_bounds(self, idx):
        if idx in (0, self.num_stations-1, 7):  # terminals + Cubao
            return (40, 150)
        return (10, 70)

    def _simulate_arrivals(self):
        amin, amax = self._arrival_bounds(self.station_idx)
        base = random.randint(amin, amax)
        mult = self._time_multiplier(self.sim_hour)

        # ✅ Passenger Surge Scaling
        surge_factor = 1.0 + (self.steps / 2000) * 2.0
        return max(0, int(round(base * mult * surge_factor)))

    def reset(self):
        self.capacity = self.initial_capacity
        self.passengers_onboard = 0
        self.raw_score = 0.0
        self.total_boarded = 0
        self.total_unused = 0.0
        self.total_config_cost = 0.0
        self.station_idx = 0
        self.direction = +1
        self.weight_window = []
        self.sim_hour = random.randint(0,23)
        self.steps = 0
        self.station_visits = 0
        self.done = False
        self.done_reason = None
        return self._get_state()

    def _get_state(self):
        return np.array([
            float(self.capacity),
            float(self.passengers_onboard),
            float(self.station_idx),
            float(self.direction),
            float(self.sim_hour)
        ], dtype=np.float32)

    # ----------------- main step -----------------
    def step(self, action):
        if self.done:
            raise RuntimeError("Environment is done. Call reset().")

        # action effects
        if action == 0:  # Dagdag
            self.capacity += 100
            cost = 10.0
            weight = 1.0
        elif action == 1:  # Lapad
            self.capacity += 50
            cost = 5.0
            weight = 0.5
        else:
            cost = 0.0
            weight = 0.0

        # config penalty (small immediate penalty)
        config_penalty = 0.5 * cost
        self.total_config_cost += cost
        self.raw_score -= config_penalty

        # ✅ Soft Collapse Pressure
        collapse_threshold = max(3.0, self.base_collapse_threshold - (self.steps / 200))
        self.weight_window.append(weight)
        if len(self.weight_window) > self.window_size:
            self.weight_window.pop(0)
        if sum(self.weight_window) >= collapse_threshold:
            self.done = True
            self.done_reason = f"Collapse at station {self.stations[self.station_idx]}"
            self.raw_score -= 200.0
            return self._get_state(), -500.0, True, {"reason": self.done_reason}

        # random alighting
        if self.passengers_onboard > 0:
            alight = random.randint(0, self.passengers_onboard)
            self.passengers_onboard -= alight

        # terminal reset
        if self.station_idx in (0, self.num_stations-1):
            self.passengers_onboard = 0

        # arrivals + boarding
        arrivals = self._simulate_arrivals()
        space = max(0, self.capacity - self.passengers_onboard)
        boarded = min(arrivals, space)
        self.passengers_onboard += boarded

        unused = max(0, self.capacity - self.passengers_onboard)

        # Reward for boarding
        reward_board = 1.5 * boarded  # ✅ Lowered multiplier to reduce runaway positive scores

        # Penalty for unused space
        penalty_unused = 0.2 * unused   # ✅ Stronger penalty to discourage overbuilding

        # Penalty for overcapacity / collapse pressure
        penalty_collapse = 0.3 * max(0, (self.passengers_onboard - self.capacity))

        # Config penalty (cost of expanding capacity)
        config_penalty = 0.8 * cost     # ✅ Make choices matter more

        # Station reward formula
        station_reward = reward_board - penalty_unused - penalty_collapse - config_penalty


        # update stats
        self.raw_score += station_reward
        self.total_boarded += boarded
        self.total_unused += unused
        self.station_visits += 1
        self.steps += 1

        # advance time
        self.sim_hour = (self.sim_hour + random.randint(0,2)) % 24

        # station movement
        next_idx = self.station_idx + self.direction
        if next_idx < 0 or next_idx >= self.num_stations:
            self.direction *= -1
            next_idx = self.station_idx + self.direction
            self.passengers_onboard = 0
        self.station_idx = next_idx

        # stop if too long
        if self.steps >= self.max_steps:
            self.done = True
            self.done_reason = "Max steps reached."

        difficulty_scale = 1.0 + (self.steps / 1000)  # grows over time
        station_reward *= difficulty_scale


        return self._get_state(), station_reward - (0.1 * cost), self.done, {}

    def final_score(self):
        distance_bonus = self.station_visits * 50
        effective_score = self.raw_score + distance_bonus
        S_min = -50 * self.station_visits
        S_max = 200 * self.station_visits
        normalized = round(1 + ((effective_score - S_min) / (S_max - S_min)) * 99)
        return max(1, min(100, normalized)), effective_score


# ===============================
# ASCII DISPLAY
# ===============================
def draw_train(env):
    track = ["-"] * env.num_stations
    idx = env.station_idx
    track[idx] = "🚉"
    train = "🚂" if env.direction == 1 else "🚋"
    print("\n" + "".join(track))
    print(" " * idx + train)
    print(f"📍 {env.stations[idx]} | Cap: {env.capacity} | Onboard: {env.passengers_onboard}")

# %%
# PLAY FUNCTION V1 (OLD)
def play_game(auto=True, max_rounds=40, delay=0.3):
    env = TrainGameEnv(initial_capacity=100)
    print("🚆 Welcome to Dagdag o Lapad 🚆")
    print("Actions: 0 = Dagdag, 1 = Lapad, 2 = None\n")

    for _ in range(max_rounds):
        draw_train(env)
        if auto:
            action = random.choice([0, 1, 2])
            print(f"🎲 Random Agent chose: {action}")
        else:
            try:
                action = int(input("Choose [0=Dagdag, 1=Lapad, 2=None]: "))
                if action not in [0,1,2]:
                    action = 2
            except:
                action = 2

        _, reward, done, info = env.step(action)
        print(f"✅ Reward: {reward:.2f} | Onboard: {env.passengers_onboard}\n")
        time.sleep(delay)

        if done:
            print(f"❌ Game ended: {env.done_reason}")
            break

    final_norm, final_raw = env.final_score()
    print("\n============================")
    print("🏁 Game Over!")
    print(f"📊 Raw Score: {final_raw:.2f}")
    print(f"⭐ Normalized Score: {final_norm}/100")
    print("============================")


# ===============================
# RUN SHOWCASE
# ===============================
play_game(auto=True, max_rounds=50, delay=0.2)
# Out:
# 🚆 Welcome to Dagdag o Lapad 🚆
# Actions: 0 = Dagdag, 1 = Lapad, 2 = None
#
#
# 🚉------------
# 🚂
# 📍 Recto | Cap: 100 | Onboard: 0
# 🎲 Random Agent chose: 2
# ✅ Reward: 150.15 | Onboard: 100
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 100 | Onboard: 100
# 🎲 Random Agent chose: 1
# ✅ Reward: 30.46 | Onboard: 62
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 150 | Onboard: 62
# 🎲 Random Agent chose: 0
# ✅ Reward: -4.61 | Onboard: 47
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 250 | Onboard: 47
# 🎲 Random Agent chose: 2
# ✅ Reward: 69.48 | Onboard: 71
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 250 | Onboard: 71
# 🎲 Random Agent chose: 0
# ✅ Reward: 46.94 | Onboard: 96
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 350 | Onboard: 96
# 🎲 Random Agent chose: 2
# ✅ Reward: 101.20 | Onboard: 148
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 350 | Onboard: 148
# 🎲 Random Agent chose: 2
# ✅ Reward: 136.25 | Onboard: 224
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 350 | Onboard: 224
# 🎲 Random Agent chose: 2
# ✅ Reward: 131.75 | Onboard: 246
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 350 | Onboard: 246
# 🎲 Random Agent chose: 2
# ✅ Reward: 25.63 | Onboard: 207
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 350 | Onboard: 207
# 🎲 Random Agent chose: 2
# ✅ Reward: 42.52 | Onboard: 163
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 350 | Onboard: 163
# 🎲 Random Agent chose: 2
# ✅ Reward: -27.60 | Onboard: 41
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 350 | Onboard: 41
# 🎲 Random Agent chose: 1
# ✅ Reward: -48.17 | Onboard: 42
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 400 | Onboard: 42
# 🎲 Random Agent chose: 2
# ✅ Reward: 60.17 | Onboard: 0
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 400 | Onboard: 0
# 🎲 Random Agent chose: 2
# ✅ Reward: -41.47 | Onboard: 23
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 400 | Onboard: 23
# 🎲 Random Agent chose: 0
# ✅ Reward: -89.51 | Onboard: 14
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 500 | Onboard: 14
# 🎲 Random Agent chose: 2
# ✅ Reward: -57.40 | Onboard: 30
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 500 | Onboard: 30
# 🎲 Random Agent chose: 2
# ✅ Reward: -55.93 | Onboard: 45
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 500 | Onboard: 45
# 🎲 Random Agent chose: 0
# ✅ Reward: 2.05 | Onboard: 115
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 600 | Onboard: 115
# 🎲 Random Agent chose: 0
# ✅ Reward: -18.93 | Onboard: 127
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 700 | Onboard: 127
# 🎲 Random Agent chose: 2
# ✅ Reward: -29.78 | Onboard: 134
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 700 | Onboard: 134
# 🎲 Random Agent chose: 1
# ✅ Reward: -110.05 | Onboard: 91
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 750 | Onboard: 91
# 🎲 Random Agent chose: 0
# ✅ Reward: -140.61 | Onboard: 57
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 850 | Onboard: 57
# 🎲 Random Agent chose: 2
# ✅ Reward: -131.66 | Onboard: 49
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 850 | Onboard: 49
# 🎲 Random Agent chose: 0
# ✅ Reward: -139.44 | Onboard: 74
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 950 | Onboard: 74
# 🎲 Random Agent chose: 2
# ✅ Reward: 3.89 | Onboard: 0
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 950 | Onboard: 0
# 🎲 Random Agent chose: 2
# ✅ Reward: -83.31 | Onboard: 64
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 950 | Onboard: 64
# 🎲 Random Agent chose: 1
# ✅ Reward: 20.14 | Onboard: 138
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 1000 | Onboard: 138
# 🎲 Random Agent chose: 2
# ✅ Reward: -72.78 | Onboard: 91
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 1000 | Onboard: 91
# 🎲 Random Agent chose: 0
# ✅ Reward: -140.84 | Onboard: 63
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 1100 | Onboard: 63
# 🎲 Random Agent chose: 1
# ✅ Reward: -196.20 | Onboard: 55
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 1150 | Onboard: 55
# 🎲 Random Agent chose: 1
# ✅ Reward: -205.26 | Onboard: 62
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 1200 | Onboard: 62
# 🎲 Random Agent chose: 0
# ✅ Reward: -180.46 | Onboard: 103
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 1300 | Onboard: 103
# 🎲 Random Agent chose: 0
# ✅ Reward: -262.45 | Onboard: 32
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 1400 | Onboard: 32
# 🎲 Random Agent chose: 1
# ✅ Reward: -251.14 | Onboard: 33
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 1450 | Onboard: 33
# 🎲 Random Agent chose: 1
# ✅ Reward: -192.39 | Onboard: 98
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 1500 | Onboard: 98
# 🎲 Random Agent chose: 1
# ✅ Reward: -282.91 | Onboard: 57
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 1550 | Onboard: 57
# 🎲 Random Agent chose: 1
# ✅ Reward: -27.98 | Onboard: 0
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 1600 | Onboard: 0
# 🎲 Random Agent chose: 2
# ✅ Reward: -228.05 | Onboard: 59
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 1600 | Onboard: 59
# 🎲 Random Agent chose: 0
# ✅ Reward: -286.10 | Onboard: 68
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 1700 | Onboard: 68
# 🎲 Random Agent chose: 1
# ✅ Reward: -335.59 | Onboard: 24
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 1750 | Onboard: 24
# 🎲 Random Agent chose: 1
# ✅ Reward: -223.07 | Onboard: 91
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 1800 | Onboard: 91
# 🎲 Random Agent chose: 2
# ✅ Reward: -89.51 | Onboard: 223
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 1800 | Onboard: 223
# 🎲 Random Agent chose: 2
# ✅ Reward: -337.83 | Onboard: 98
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 1800 | Onboard: 98
# 🎲 Random Agent chose: 2
# ✅ Reward: -356.94 | Onboard: 23
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 1800 | Onboard: 23
# 🎲 Random Agent chose: 0
# ✅ Reward: -329.97 | Onboard: 51
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 1900 | Onboard: 51
# 🎲 Random Agent chose: 1
# ✅ Reward: -300.28 | Onboard: 87
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 1950 | Onboard: 87
# 🎲 Random Agent chose: 1
# ✅ Reward: -303.50 | Onboard: 108
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 2000 | Onboard: 108
# 🎲 Random Agent chose: 1
# ✅ Reward: -184.21 | Onboard: 151
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 2050 | Onboard: 151
# 🎲 Random Agent chose: 1
# ✅ Reward: -90.40 | Onboard: 0
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 2100 | Onboard: 0
# 🎲 Random Agent chose: 2
# ✅ Reward: -283.92 | Onboard: 88
#
#
# ============================
# 🏁 Game Over!
# 📊 Raw Score: -2688.40
# ⭐ Normalized Score: 1/100
# ============================

# %%
# TRAIN GAME V2 - OPTIMIZED SCORING
# Efficient transit management simulation with realistic scoring

import random
import time
import numpy as np

class TrainGameEnv:
    def __init__(self, initial_capacity=100, seed=None, verbose=False):
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)

        # Core game state
        self.initial_capacity = initial_capacity
        self.capacity = initial_capacity
        self.passengers_onboard = 0

        # Performance tracking
        self.raw_score = 0.0
        self.total_boarded = 0
        self.total_unused = 0.0
        self.total_config_cost = 0.0
        self.peak_inefficiency = 0  # Track worst excess capacity

        # Station configuration (LRT-2 line)
        self.stations = [
            "Recto", "Legarda", "Pureza", "V. Mapa", "J. Ruiz", "Gilmore",
            "Betty Go", "Cubao", "Anonas", "Katipunan",
            "Santolan", "Marikina", "Antipolo"
        ]
        self.num_stations = len(self.stations)
        self.station_idx = 0
        self.direction = +1

        # Infrastructure stress management
        self.weight_window = []
        self.window_size = 10
        self.base_collapse_threshold = 10.0

        # Time management (04:00-22:00 operating hours)
        self.sim_minutes = random.randint(4 * 60, 22 * 60 - 1)
        self.steps = 0
        self.max_steps = 2000
        self.station_visits = 0

        # Efficiency tracking
        self.previous_onboard = 0

        self.done = False
        self.done_reason = None
        self.verbose = verbose

    # ----------------- core simulation methods -----------------
    def _time_multiplier(self, hour):
        """Get passenger multiplier based on time of day"""
        if 6 <= hour <= 8:   return 1.9  # Morning rush
        if 11 <= hour <= 13: return 1.6  # Lunch rush  
        if 17 <= hour <= 19: return 1.9  # Evening rush
        return 0.8 if random.random() < 0.45 else 1.0

    def _arrival_bounds(self, idx):
        """Get min/max arrivals for station type"""
        if idx in (0, self.num_stations-1, 7):  # Terminals + major hub
            return (40, 150)
        return (10, 70)

    def _simulate_arrivals(self):
        """Calculate arriving passengers at current station"""
        amin, amax = self._arrival_bounds(self.station_idx)
        base = random.randint(amin, amax)
        
        current_hour = self.sim_minutes // 60
        mult = self._time_multiplier(current_hour)

        # Passenger volume increases over time
        surge_factor = 1.0 + (self.steps / 2000) * 2.0
        return max(0, int(round(base * mult * surge_factor)))

    def _calculate_efficiency_penalty(self, unused_space, alighted_passengers, previous_onboard, current_hour):
        """Calculate penalty based on operational efficiency"""
        base_penalty = 0.3 * unused_space
        penalty_growth = 1.0 + (self.steps / 1000)
        
        # Reduced penalty for empty trains starting service
        if previous_onboard == 0:
            return base_penalty * penalty_growth * 0.1
        
        alighting_ratio = alighted_passengers / previous_onboard
        
        # Time-based efficiency expectations
        if 6 <= current_hour <= 8 or 17 <= current_hour <= 19:
            expected_efficiency = 0.7  # Rush hour
        elif 11 <= current_hour <= 13:
            expected_efficiency = 0.6  # Lunch hour
        else:
            expected_efficiency = 0.4  # Off-peak

        # Station-type efficiency expectations
        if self.station_idx in (0, self.num_stations-1):
            station_factor = 0.9  # Terminals
        elif self.station_idx == 7:
            station_factor = 0.8  # Major hub
        else:
            station_factor = 0.6  # Regular stations

        target_efficiency = max(0.3, min(0.95, expected_efficiency * station_factor))
        
        # Larger capacity = higher waste penalty
        capacity_factor = 0.5 + (self.capacity / 2000)
        
        # Efficiency-based penalty scaling
        if alighting_ratio > target_efficiency + 0.15:
            efficiency_multiplier = 0.1  # High efficiency
        elif alighting_ratio > target_efficiency:
            efficiency_multiplier = 0.3  # Good efficiency
        elif alighting_ratio > target_efficiency * 0.7:
            efficiency_multiplier = 0.6  # Moderate efficiency
        else:
            efficiency_multiplier = 1.2  # Poor efficiency
        
        efficiency_multiplier *= capacity_factor
        return base_penalty * penalty_growth * efficiency_multiplier

    def reset(self):
        """Reset environment to initial state"""
        self.capacity = self.initial_capacity
        self.passengers_onboard = 0
        self.raw_score = 0.0
        self.total_boarded = 0
        self.total_unused = 0.0
        self.total_config_cost = 0.0
        self.peak_inefficiency = 0
        self.station_idx = 0
        self.direction = +1
        self.weight_window = []
        
        self.sim_minutes = random.randint(4 * 60, 22 * 60 - 1)
        self.steps = 0
        self.station_visits = 0
        self.previous_onboard = 0
        self.done = False
        self.done_reason = None
        return self._get_state()

    def _get_state(self):
        """Get current environment state vector"""
        hour = self.sim_minutes // 60
        minute = self.sim_minutes % 60
        return np.array([
            float(self.capacity),
            float(self.passengers_onboard),
            float(self.station_idx),
            float(self.direction),
            float(hour),
            float(minute)
        ], dtype=np.float32)

    def step(self, action):
        """Execute one game step with given action"""
        if self.done:
            raise RuntimeError("Environment is done. Call reset().")

        alighted_passengers = 0
        self.previous_onboard = self.passengers_onboard

        # Process capacity actions
        if action == 0:  # Add carriage (+100 capacity)
            self.capacity += 100
            cost, weight = 10.0, 1.0
        elif action == 1:  # Widen carriage (+50 capacity)  
            self.capacity += 50
            cost, weight = 5.0, 0.5
        else:  # No action
            cost, weight = 0.0, 0.0

        # Apply configuration cost penalty
        config_penalty = 2.0 * cost
        self.total_config_cost += cost
        self.raw_score -= config_penalty

        # Check for infrastructure collapse
        collapse_threshold = max(3.0, self.base_collapse_threshold - (self.steps / 200))
        self.weight_window.append(weight)
        if len(self.weight_window) > self.window_size:
            self.weight_window.pop(0)
        if sum(self.weight_window) >= collapse_threshold:
            self.done = True
            self.done_reason = f"Collapse at station {self.stations[self.station_idx]}"
            self.raw_score -= 500.0
            return self._get_state(), -1000.0, True, {"reason": self.done_reason, "alighted": 0}

        # Passenger alighting simulation
        if self.passengers_onboard > 0:
            alighted_passengers = random.randint(0, self.passengers_onboard)
            self.passengers_onboard -= alighted_passengers

        # Clear train at terminal stations
        if self.station_idx in (0, self.num_stations-1):
            self.passengers_onboard = 0

        # Passenger boarding simulation
        arrivals = self._simulate_arrivals()
        space = max(0, self.capacity - self.passengers_onboard)
        boarded = min(arrivals, space)
        self.passengers_onboard += boarded

        unused = max(0, self.capacity - self.passengers_onboard)
        self.peak_inefficiency = max(self.peak_inefficiency, unused)

        # Calculate rewards and penalties
        current_hour = self.sim_minutes // 60
        penalty_unused = self._calculate_efficiency_penalty(
            unused, alighted_passengers, self.previous_onboard, current_hour
        )
        
        reward_board = 1.5 * boarded
        station_reward = reward_board - penalty_unused

        # Update game state
        self.raw_score += station_reward
        self.total_boarded += boarded
        self.total_unused += unused
        self.station_visits += 1
        self.steps += 1

        # Advance simulation time
        self.sim_minutes += 5
        if self.sim_minutes >= 22 * 60:
            self.done = True
            self.done_reason = "End of operating hours (22:00)"

        # Move to next station
        next_idx = self.station_idx + self.direction
        if next_idx < 0 or next_idx >= self.num_stations:
            self.direction *= -1
            next_idx = self.station_idx + self.direction
            self.passengers_onboard = 0
        self.station_idx = next_idx

        # Check step limit
        if self.steps >= self.max_steps:
            self.done = True
            self.done_reason = "Max steps reached."

        return self._get_state(), station_reward - (0.2 * cost), self.done, {
            "alighted": alighted_passengers,
            "penalty_unused": penalty_unused,
            "efficiency_ratio": alighted_passengers / max(1, self.previous_onboard)
        }

    def final_score(self):
        """Calculate final normalized score (1-100)"""
        distance_bonus = self.station_visits * 10
        efficiency_penalty = self.peak_inefficiency * 0.1
        config_efficiency = max(0, 1 - (self.total_config_cost / (self.total_boarded + 1)))
        
        effective_score = (self.raw_score + distance_bonus - efficiency_penalty) * config_efficiency
        
        # Normalize to 1-100 scale
        S_min = -80 * self.station_visits
        S_max = 100 * self.station_visits
        normalized = round(1 + ((effective_score - S_min) / (S_max - S_min)) * 99)
        
        return max(1, min(100, normalized)), effective_score
    
    
# ===============================
# VISUALIZATION
# ===============================
def draw_train(env):
    """Display current train position and status"""
    track = ["-"] * env.num_stations
    idx = env.station_idx
    track[idx] = "🚉"
    train = "🚂" if env.direction == 1 else "🚋"
    print("\n" + "".join(track))
    print(" " * idx + train)
    print(f"📍 {env.stations[idx]} | Cap: {env.capacity} | Onboard: {env.passengers_onboard}")

# %%
# SMART RANDOM PLAY FUNCTION

def play_game_smart_random(auto=True, max_rounds=40, delay=0.3):
    env = TrainGameEnv(initial_capacity=100)
    
    # Track metrics
    total_alighted = 0
    peak_excess_space = 0
    total_excess_space = 0
    station_count = 0
    
    print("🚆 Welcome to Dagdag o Lapad 🚆")
    print("Actions: 0 = Dagdag, 1 = Lapad, 2 = None")
    
    # Display starting time
    start_hour = env.sim_minutes // 60
    start_minute = env.sim_minutes % 60
    print(f"🕐 Starting at: {start_hour:02d}:{start_minute:02d}\n")

    for _ in range(max_rounds):
        draw_train(env)
        
        # Display current time and direction
        current_hour = env.sim_minutes // 60
        current_minute = env.sim_minutes % 60
        direction = "NB" if env.direction == 1 else "SB"
        print(f"🕐 Time: {current_hour:02d}:{current_minute:02d} | Direction: {direction}")
        
        if auto:
            # SMART RANDOM: Weight actions based on current situation
            utilization = env.passengers_onboard / max(1, env.capacity)
            current_hour = env.sim_minutes // 60
            
            # Base weights (favor doing nothing)
            weights = [0.2, 0.2, 0.6]  # [Dagdag, Lapad, None]
            
            # Adjust weights based on utilization
            if utilization > 0.8:  # High utilization - favor expansion
                weights = [0.5, 0.3, 0.2]
            elif utilization < 0.3:  # Low utilization - favor doing nothing
                weights = [0.1, 0.1, 0.8]
            
            # Adjust based on time of day (rush hour vs off-peak)
            if 6 <= current_hour <= 8 or 17 <= current_hour <= 19:  # Rush hours
                weights = [weights[0] + 0.1, weights[1] + 0.1, weights[2] - 0.2]
            
            # Choose action with weighted probabilities
            action = random.choices([0, 1, 2], weights=weights)[0]
            action_names = {0: "Dagdag", 1: "Lapad", 2: "None"}
            print(f"🎯 Smart Random chose: {action} ({action_names[action]})")
            print(f"📊 Utilization: {utilization:.1%} | Weights: Dagdag:{weights[0]:.1%}, Lapad:{weights[1]:.1%}, None:{weights[2]:.1%}")
        else:
            try:
                action = int(input("Choose [0=Dagdag, 1=Lapad, 2=None]: "))
                if action not in [0,1,2]:
                    action = 2
            except:
                action = 2

        # Store current state before step
        previous_onboard = env.passengers_onboard
        
        # Take step and get the actual alighted count from the environment
        state, reward, done, info = env.step(action)
        
        alighted = info.get('alighted', 0)
        total_alighted += alighted
        
        # Calculate excess space metrics
        excess_space = max(0, env.capacity - env.passengers_onboard)
        total_excess_space += excess_space
        peak_excess_space = max(peak_excess_space, excess_space)
        station_count += 1
        
        print(f"✅ Reward: {reward:.2f} | Onboard: {env.passengers_onboard} | Alighted: {alighted}")
        print(f"📊 Excess Space: {excess_space} | Capacity: {env.capacity}\n")
        time.sleep(delay)

        if done:
            print(f"❌ Game ended: {env.done_reason}")
            break

    # Calculate final metrics
    final_norm, final_raw = env.final_score()
    average_excess_space = total_excess_space / station_count if station_count > 0 else 0
    
    print("\n" + "="*50)
    print("🏁 GAME OVER - FINAL STATISTICS")
    print("="*50)
    print(f"📊 Raw Score: {final_raw:.2f}")
    print(f"⭐ Normalized Score: {final_norm}/100")
    print(f"👥 Total Passengers Carried: {env.total_boarded}")
    print(f"🚪 Total Passengers Alighted: {total_alighted}")
    print(f"📦 Average Excess Space: {average_excess_space:.1f}")
    print(f"📈 Peak Capacity Inefficiency: {peak_excess_space}")
    print(f"🛑 Stations Visited: {env.station_visits}")
    print(f"⏱️  Total Steps: {env.steps}")
    print(f"💰 Total Configuration Cost: {env.total_config_cost:.1f}")
    print("="*50)

# Run smart random
play_game_smart_random(auto=True, max_rounds=50, delay=0.2)
# Out:
# 🚆 Welcome to Dagdag o Lapad 🚆
# Actions: 0 = Dagdag, 1 = Lapad, 2 = None
# 🕐 Starting at: 12:58
#
#
# 🚉------------
# 🚂
# 📍 Recto | Cap: 100 | Onboard: 0
# 🕐 Time: 12:58 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 0.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 150.00 | Onboard: 100 | Alighted: 0
# 📊 Excess Space: 0 | Capacity: 100
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 100 | Onboard: 100
# 🕐 Time: 13:03 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 100.0% | Weights: Dagdag:50.0%, Lapad:30.0%, None:20.0%
# ✅ Reward: 76.50 | Onboard: 100 | Alighted: 51
# 📊 Excess Space: 0 | Capacity: 100
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 100 | Onboard: 100
# 🕐 Time: 13:08 | Direction: NB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 100.0% | Weights: Dagdag:50.0%, Lapad:30.0%, None:20.0%
# ✅ Reward: 87.68 | Onboard: 150 | Alighted: 17
# 📊 Excess Space: 50 | Capacity: 200
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 200 | Onboard: 150
# 🕐 Time: 13:13 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 75.0% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 93.00 | Onboard: 200 | Alighted: 12
# 📊 Excess Space: 0 | Capacity: 200
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 200 | Onboard: 200
# 🕐 Time: 13:18 | Direction: NB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 100.0% | Weights: Dagdag:50.0%, Lapad:30.0%, None:20.0%
# ✅ Reward: 41.54 | Onboard: 72 | Alighted: 160
# 📊 Excess Space: 228 | Capacity: 300
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 300 | Onboard: 72
# 🕐 Time: 13:23 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 24.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 111.48 | Onboard: 95 | Alighted: 54
# 📊 Excess Space: 205 | Capacity: 300
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 300 | Onboard: 95
# 🕐 Time: 13:28 | Direction: NB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 31.7% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 96.01 | Onboard: 124 | Alighted: 48
# 📊 Excess Space: 276 | Capacity: 400
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 400 | Onboard: 124
# 🕐 Time: 13:33 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 31.0% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 159.60 | Onboard: 173 | Alighted: 67
# 📊 Excess Space: 227 | Capacity: 400
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 400 | Onboard: 173
# 🕐 Time: 13:38 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 43.2% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 90.92 | Onboard: 256 | Alighted: 2
# 📊 Excess Space: 144 | Capacity: 400
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 400 | Onboard: 256
# 🕐 Time: 13:43 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 64.0% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 138.58 | Onboard: 215 | Alighted: 136
# 📊 Excess Space: 185 | Capacity: 400
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 400 | Onboard: 215
# 🕐 Time: 13:48 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 53.8% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 24.74 | Onboard: 232 | Alighted: 28
# 📊 Excess Space: 168 | Capacity: 400
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 400 | Onboard: 232
# 🕐 Time: 13:53 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 58.0% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 6.93 | Onboard: 132 | Alighted: 116
# 📊 Excess Space: 268 | Capacity: 400
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 400 | Onboard: 132
# 🕐 Time: 13:58 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 33.0% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 222.42 | Onboard: 0 | Alighted: 67
# 📊 Excess Space: 400 | Capacity: 400
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 400 | Onboard: 0
# 🕐 Time: 14:03 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 0.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 53.65 | Onboard: 43 | Alighted: 0
# 📊 Excess Space: 357 | Capacity: 400
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 400 | Onboard: 43
# 🕐 Time: 14:08 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 10.8% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 76.07 | Onboard: 88 | Alighted: 19
# 📊 Excess Space: 312 | Capacity: 400
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 400 | Onboard: 88
# 🕐 Time: 14:13 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 22.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 11.39 | Onboard: 102 | Alighted: 19
# 📊 Excess Space: 298 | Capacity: 400
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 400 | Onboard: 102
# 🕐 Time: 14:18 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 25.5% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 98.02 | Onboard: 73 | Alighted: 99
# 📊 Excess Space: 327 | Capacity: 400
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 400 | Onboard: 73
# 🕐 Time: 14:23 | Direction: SB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 18.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 113.69 | Onboard: 115 | Alighted: 41
# 📊 Excess Space: 385 | Capacity: 500
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 500 | Onboard: 115
# 🕐 Time: 14:28 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 23.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 86.08 | Onboard: 67 | Alighted: 112
# 📊 Excess Space: 433 | Capacity: 500
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 500 | Onboard: 67
# 🕐 Time: 14:33 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 13.4% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 73.26 | Onboard: 104 | Alighted: 30
# 📊 Excess Space: 396 | Capacity: 500
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 500 | Onboard: 104
# 🕐 Time: 14:38 | Direction: SB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 20.8% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 47.61 | Onboard: 53 | Alighted: 93
# 📊 Excess Space: 547 | Capacity: 600
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 600 | Onboard: 53
# 🕐 Time: 14:43 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 8.8% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 58.94 | Onboard: 67 | Alighted: 34
# 📊 Excess Space: 533 | Capacity: 600
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 600 | Onboard: 67
# 🕐 Time: 14:48 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 11.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 1.72 | Onboard: 73 | Alighted: 21
# 📊 Excess Space: 527 | Capacity: 600
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 600 | Onboard: 73
# 🕐 Time: 14:53 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 12.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 70.92 | Onboard: 117 | Alighted: 27
# 📊 Excess Space: 483 | Capacity: 600
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 600 | Onboard: 117
# 🕐 Time: 14:58 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 19.5% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 15.11 | Onboard: 0 | Alighted: 25
# 📊 Excess Space: 600 | Capacity: 600
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 600 | Onboard: 0
# 🕐 Time: 15:03 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 0.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 45.84 | Onboard: 42 | Alighted: 0
# 📊 Excess Space: 558 | Capacity: 600
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 600 | Onboard: 42
# 🕐 Time: 15:08 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 7.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 6.92 | Onboard: 28 | Alighted: 28
# 📊 Excess Space: 572 | Capacity: 600
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 600 | Onboard: 28
# 🕐 Time: 15:13 | Direction: NB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 4.7% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -126.10 | Onboard: 76 | Alighted: 0
# 📊 Excess Space: 624 | Capacity: 700
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 700 | Onboard: 76
# 🕐 Time: 15:18 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 10.9% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -170.89 | Onboard: 90 | Alighted: 0
# 📊 Excess Space: 610 | Capacity: 700
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 700 | Onboard: 90
# 🕐 Time: 15:23 | Direction: NB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 12.9% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -140.54 | Onboard: 137 | Alighted: 8
# 📊 Excess Space: 663 | Capacity: 800
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 800 | Onboard: 137
# 🕐 Time: 15:28 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 17.1% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 10.00 | Onboard: 27 | Alighted: 131
# 📊 Excess Space: 773 | Capacity: 800
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 800 | Onboard: 27
# 🕐 Time: 15:33 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 3.4% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 66.62 | Onboard: 68 | Alighted: 17
# 📊 Excess Space: 732 | Capacity: 800
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 800 | Onboard: 68
# 🕐 Time: 15:38 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 8.5% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 17.66 | Onboard: 34 | Alighted: 60
# 📊 Excess Space: 766 | Capacity: 800
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 800 | Onboard: 34
# 🕐 Time: 15:43 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 4.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -44.51 | Onboard: 35 | Alighted: 12
# 📊 Excess Space: 765 | Capacity: 800
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 800 | Onboard: 35
# 🕐 Time: 15:48 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 4.4% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 34.42 | Onboard: 45 | Alighted: 27
# 📊 Excess Space: 755 | Capacity: 800
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 800 | Onboard: 45
# 🕐 Time: 15:53 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 5.6% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 58.68 | Onboard: 55 | Alighted: 43
# 📊 Excess Space: 745 | Capacity: 800
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 800 | Onboard: 55
# 🕐 Time: 15:58 | Direction: NB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 6.9% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 93.02 | Onboard: 0 | Alighted: 25
# 📊 Excess Space: 900 | Capacity: 900
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 900 | Onboard: 0
# 🕐 Time: 16:03 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 0.0% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 4.15 | Onboard: 21 | Alighted: 0
# 📊 Excess Space: 879 | Capacity: 900
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 900 | Onboard: 21
# 🕐 Time: 16:08 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 2.3% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -255.96 | Onboard: 48 | Alighted: 4
# 📊 Excess Space: 852 | Capacity: 900
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 900 | Onboard: 48
# 🕐 Time: 16:13 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 5.3% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -231.81 | Onboard: 83 | Alighted: 4
# 📊 Excess Space: 817 | Capacity: 900
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 900 | Onboard: 83
# 🕐 Time: 16:18 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 9.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -268.88 | Onboard: 85 | Alighted: 12
# 📊 Excess Space: 815 | Capacity: 900
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 900 | Onboard: 85
# 🕐 Time: 16:23 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 9.4% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -192.14 | Onboard: 137 | Alighted: 1
# 📊 Excess Space: 763 | Capacity: 900
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 900 | Onboard: 137
# 🕐 Time: 16:28 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 15.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -11.33 | Onboard: 133 | Alighted: 42
# 📊 Excess Space: 767 | Capacity: 900
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 900 | Onboard: 133
# 🕐 Time: 16:33 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 14.8% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 59.83 | Onboard: 87 | Alighted: 102
# 📊 Excess Space: 813 | Capacity: 900
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 900 | Onboard: 87
# 🕐 Time: 16:38 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 9.7% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 15.66 | Onboard: 65 | Alighted: 49
# 📊 Excess Space: 835 | Capacity: 900
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 900 | Onboard: 65
# 🕐 Time: 16:43 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 7.2% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 33.72 | Onboard: 68 | Alighted: 36
# 📊 Excess Space: 832 | Capacity: 900
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 900 | Onboard: 68
# 🕐 Time: 16:48 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 7.6% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -2.17 | Onboard: 22 | Alighted: 62
# 📊 Excess Space: 878 | Capacity: 900
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 900 | Onboard: 22
# 🕐 Time: 16:53 | Direction: SB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 2.4% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: -223.70 | Onboard: 70 | Alighted: 1
# 📊 Excess Space: 830 | Capacity: 900
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 900 | Onboard: 70
# 🕐 Time: 16:58 | Direction: SB
# 🎯 Smart Random chose: 0 (Dagdag)
# 📊 Utilization: 7.8% | Weights: Dagdag:10.0%, Lapad:10.0%, None:80.0%
# ✅ Reward: 26.29 | Onboard: 0 | Alighted: 40
# 📊 Excess Space: 1000 | Capacity: 1000
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 1000 | Onboard: 0
# 🕐 Time: 17:03 | Direction: NB
# 🎯 Smart Random chose: 2 (None)
# 📊 Utilization: 0.0% | Weights: Dagdag:20.0%, Lapad:20.0%, None:60.0%
# ✅ Reward: 176.81 | Onboard: 136 | Alighted: 0
# 📊 Excess Space: 864 | Capacity: 1000
#
#
# ==================================================
# 🏁 GAME OVER - FINAL STATISTICS
# ==================================================
# 📊 Raw Score: 1189.26
# ⭐ Normalized Score: 58/100
# 👥 Total Passengers Carried: 2759
# 🚪 Total Passengers Alighted: 1982
# 📦 Average Excess Space: 535.1
# 📈 Peak Capacity Inefficiency: 1000
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 90.0
# ==================================================

# %%
# REGULAR RANDOM PLAY FUNCTION

def play_game(auto=True, max_rounds=40, delay=0.3):
    env = TrainGameEnv(initial_capacity=100)
    
    # Track metrics
    total_alighted = 0
    peak_excess_space = 0
    total_excess_space = 0
    station_count = 0
    
    print("🚆 Welcome to Dagdag o Lapad 🚆")
    print("Actions: 0 = Dagdag, 1 = Lapad, 2 = None")
    
    # Display starting time
    start_hour = env.sim_minutes // 60
    start_minute = env.sim_minutes % 60
    print(f"🕐 Starting at: {start_hour:02d}:{start_minute:02d}\n")

    for _ in range(max_rounds):
        draw_train(env)
        
        # Display current time and direction
        current_hour = env.sim_minutes // 60
        current_minute = env.sim_minutes % 60
        direction = "NB" if env.direction == 1 else "SB"
        print(f"🕐 Time: {current_hour:02d}:{current_minute:02d} | Direction: {direction}")
        
        if auto:
            action = random.choice([0, 1, 2])
            print(f"🎲 Random Agent chose: {action}")
        else:
            try:
                action = int(input("Choose [0=Dagdag, 1=Lapad, 2=None]: "))
                if action not in [0,1,2]:
                    action = 2
            except:
                action = 2

        # Store current state before step
        previous_onboard = env.passengers_onboard
        
        # Take step and get the actual alighted count from the environment
        state, reward, done, info = env.step(action)
        
        # NEW: Get alighted passengers from the environment's internal tracking
        # We'll need to modify the step method to return this info
        alighted = info.get('alighted', 0)
        total_alighted += alighted
        
        # Calculate excess space metrics
        excess_space = max(0, env.capacity - env.passengers_onboard)
        total_excess_space += excess_space
        peak_excess_space = max(peak_excess_space, excess_space)
        station_count += 1
        
        print(f"✅ Reward: {reward:.2f} | Onboard: {env.passengers_onboard} | Alighted: {alighted}")
        print(f"📊 Excess Space: {excess_space} | Capacity: {env.capacity}\n")
        time.sleep(delay)

        if done:
            print(f"❌ Game ended: {env.done_reason}")
            break

    # Calculate final metrics
    final_norm, final_raw = env.final_score()
    average_excess_space = total_excess_space / station_count if station_count > 0 else 0
    
    print("\n" + "="*50)
    print("🏁 GAME OVER - FINAL STATISTICS")
    print("="*50)
    print(f"📊 Raw Score: {final_raw:.2f}")
    print(f"⭐ Normalized Score: {final_norm}/100")
    print(f"👥 Total Passengers Carried: {env.total_boarded}")
    print(f"🚪 Total Passengers Alighted: {total_alighted}")
    print(f"📦 Average Excess Space: {average_excess_space:.1f}")
    print(f"📈 Peak Capacity Inefficiency: {peak_excess_space}")
    print(f"🛑 Stations Visited: {env.station_visits}")
    print(f"⏱️  Total Steps: {env.steps}")
    print(f"💰 Total Configuration Cost: {env.total_config_cost:.1f}")
    print("="*50)

# ===============================
# RUN SHOWCASE
# ===============================
play_game(auto=True, max_rounds=50, delay=0.2)
# Out:
# 🚆 Welcome to Dagdag o Lapad 🚆
# Actions: 0 = Dagdag, 1 = Lapad, 2 = None
# 🕐 Starting at: 09:22
#
#
# 🚉------------
# 🚂
# 📍 Recto | Cap: 100 | Onboard: 0
# 🕐 Time: 09:22 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: 120.52 | Onboard: 84 | Alighted: 0
# 📊 Excess Space: 116 | Capacity: 200
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 200 | Onboard: 84
# 🕐 Time: 09:27 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: 11.43 | Onboard: 114 | Alighted: 8
# 📊 Excess Space: 186 | Capacity: 300
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 300 | Onboard: 114
# 🕐 Time: 09:32 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: 3.30 | Onboard: 80 | Alighted: 51
# 📊 Excess Space: 320 | Capacity: 400
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 400 | Onboard: 80
# 🕐 Time: 09:37 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: 51.29 | Onboard: 96 | Alighted: 31
# 📊 Excess Space: 304 | Capacity: 400
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 400 | Onboard: 96
# 🕐 Time: 09:42 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: -16.34 | Onboard: 122 | Alighted: 10
# 📊 Excess Space: 278 | Capacity: 400
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 400 | Onboard: 122
# 🕐 Time: 09:47 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: 38.37 | Onboard: 86 | Alighted: 66
# 📊 Excess Space: 314 | Capacity: 400
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 400 | Onboard: 86
# 🕐 Time: 09:52 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: 53.70 | Onboard: 45 | Alighted: 85
# 📊 Excess Space: 455 | Capacity: 500
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 500 | Onboard: 45
# 🕐 Time: 09:57 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: 71.90 | Onboard: 76 | Alighted: 25
# 📊 Excess Space: 474 | Capacity: 550
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 550 | Onboard: 76
# 🕐 Time: 10:02 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: 30.65 | Onboard: 48 | Alighted: 58
# 📊 Excess Space: 552 | Capacity: 600
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 600 | Onboard: 48
# 🕐 Time: 10:07 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: -132.77 | Onboard: 87 | Alighted: 0
# 📊 Excess Space: 613 | Capacity: 700
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 700 | Onboard: 87
# 🕐 Time: 10:12 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: -167.84 | Onboard: 89 | Alighted: 12
# 📊 Excess Space: 611 | Capacity: 700
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 700 | Onboard: 89
# 🕐 Time: 10:17 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: -21.42 | Onboard: 74 | Alighted: 33
# 📊 Excess Space: 626 | Capacity: 700
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 700 | Onboard: 74
# 🕐 Time: 10:22 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: 43.16 | Onboard: 0 | Alighted: 31
# 📊 Excess Space: 800 | Capacity: 800
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 800 | Onboard: 0
# 🕐 Time: 10:27 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: 71.11 | Onboard: 64 | Alighted: 0
# 📊 Excess Space: 786 | Capacity: 850
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 850 | Onboard: 64
# 🕐 Time: 10:32 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: -193.38 | Onboard: 116 | Alighted: 1
# 📊 Excess Space: 784 | Capacity: 900
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 900 | Onboard: 116
# 🕐 Time: 10:37 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: -3.78 | Onboard: 48 | Alighted: 84
# 📊 Excess Space: 902 | Capacity: 950
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 950 | Onboard: 48
# 🕐 Time: 10:42 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -70.32 | Onboard: 49 | Alighted: 16
# 📊 Excess Space: 1001 | Capacity: 1050
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 1050 | Onboard: 49
# 🕐 Time: 10:47 | Direction: SB
# 🎲 Random Agent chose: 2
# ✅ Reward: 41.10 | Onboard: 62 | Alighted: 35
# 📊 Excess Space: 988 | Capacity: 1050
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 1050 | Onboard: 62
# 🕐 Time: 10:52 | Direction: SB
# 🎲 Random Agent chose: 2
# ✅ Reward: -291.61 | Onboard: 94 | Alighted: 13
# 📊 Excess Space: 956 | Capacity: 1050
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 1050 | Onboard: 94
# 🕐 Time: 10:57 | Direction: SB
# 🎲 Random Agent chose: 2
# ✅ Reward: 47.14 | Onboard: 65 | Alighted: 81
# 📊 Excess Space: 985 | Capacity: 1050
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 1050 | Onboard: 65
# 🕐 Time: 11:02 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: 70.16 | Onboard: 142 | Alighted: 32
# 📊 Excess Space: 958 | Capacity: 1100
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 1100 | Onboard: 142
# 🕐 Time: 11:07 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -282.91 | Onboard: 201 | Alighted: 23
# 📊 Excess Space: 999 | Capacity: 1200
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 1200 | Onboard: 201
# 🕐 Time: 11:12 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: -198.44 | Onboard: 151 | Alighted: 70
# 📊 Excess Space: 1099 | Capacity: 1250
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 1250 | Onboard: 151
# 🕐 Time: 11:17 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: 100.70 | Onboard: 163 | Alighted: 85
# 📊 Excess Space: 1187 | Capacity: 1350
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 1350 | Onboard: 163
# 🕐 Time: 11:22 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: 127.95 | Onboard: 0 | Alighted: 163
# 📊 Excess Space: 1450 | Capacity: 1450
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 1450 | Onboard: 0
# 🕐 Time: 11:27 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: 92.70 | Onboard: 93 | Alighted: 0
# 📊 Excess Space: 1457 | Capacity: 1550
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 1550 | Onboard: 93
# 🕐 Time: 11:32 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: 74.50 | Onboard: 113 | Alighted: 70
# 📊 Excess Space: 1487 | Capacity: 1600
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 1600 | Onboard: 113
# 🕐 Time: 11:37 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: -41.99 | Onboard: 58 | Alighted: 71
# 📊 Excess Space: 1592 | Capacity: 1650
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 1650 | Onboard: 58
# 🕐 Time: 11:42 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: -634.01 | Onboard: 169 | Alighted: 4
# 📊 Excess Space: 1581 | Capacity: 1750
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 1750 | Onboard: 169
# 🕐 Time: 11:47 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: -679.97 | Onboard: 203 | Alighted: 38
# 📊 Excess Space: 1547 | Capacity: 1750
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 1750 | Onboard: 203
# 🕐 Time: 11:52 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: -106.31 | Onboard: 186 | Alighted: 94
# 📊 Excess Space: 1664 | Capacity: 1850
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 1850 | Onboard: 186
# 🕐 Time: 11:57 | Direction: NB
# 🎲 Random Agent chose: 2
# ✅ Reward: -581.13 | Onboard: 306 | Alighted: 37
# 📊 Excess Space: 1544 | Capacity: 1850
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 1850 | Onboard: 306
# 🕐 Time: 12:02 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: -816.10 | Onboard: 333 | Alighted: 21
# 📊 Excess Space: 1617 | Capacity: 1950
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 1950 | Onboard: 333
# 🕐 Time: 12:07 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: -713.62 | Onboard: 424 | Alighted: 20
# 📊 Excess Space: 1576 | Capacity: 2000
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 2000 | Onboard: 424
# 🕐 Time: 12:12 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: -335.91 | Onboard: 405 | Alighted: 107
# 📊 Excess Space: 1645 | Capacity: 2050
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 2050 | Onboard: 405
# 🕐 Time: 12:17 | Direction: NB
# 🎲 Random Agent chose: 0
# ✅ Reward: -63.74 | Onboard: 90 | Alighted: 341
# 📊 Excess Space: 2060 | Capacity: 2150
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 2150 | Onboard: 90
# 🕐 Time: 12:22 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: 125.16 | Onboard: 0 | Alighted: 71
# 📊 Excess Space: 2200 | Capacity: 2200
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 2200 | Onboard: 0
# 🕐 Time: 12:27 | Direction: SB
# 🎲 Random Agent chose: 2
# ✅ Reward: 77.01 | Onboard: 95 | Alighted: 0
# 📊 Excess Space: 2105 | Capacity: 2200
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 2200 | Onboard: 95
# 🕐 Time: 12:32 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -495.72 | Onboard: 173 | Alighted: 30
# 📊 Excess Space: 2127 | Capacity: 2300
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 2300 | Onboard: 173
# 🕐 Time: 12:37 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -524.37 | Onboard: 238 | Alighted: 45
# 📊 Excess Space: 2162 | Capacity: 2400
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 2400 | Onboard: 238
# 🕐 Time: 12:42 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: -1358.37 | Onboard: 267 | Alighted: 6
# 📊 Excess Space: 2183 | Capacity: 2450
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 2450 | Onboard: 267
# 🕐 Time: 12:47 | Direction: SB
# 🎲 Random Agent chose: 2
# ✅ Reward: 235.29 | Onboard: 330 | Alighted: 170
# 📊 Excess Space: 2120 | Capacity: 2450
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 2450 | Onboard: 330
# 🕐 Time: 12:52 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: -303.09 | Onboard: 248 | Alighted: 127
# 📊 Excess Space: 2252 | Capacity: 2500
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 2500 | Onboard: 248
# 🕐 Time: 12:57 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -5.72 | Onboard: 137 | Alighted: 201
# 📊 Excess Space: 2463 | Capacity: 2600
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 2600 | Onboard: 137
# 🕐 Time: 13:02 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: 13.69 | Onboard: 149 | Alighted: 97
# 📊 Excess Space: 2551 | Capacity: 2700
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 2700 | Onboard: 149
# 🕐 Time: 13:07 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -104.67 | Onboard: 69 | Alighted: 120
# 📊 Excess Space: 2731 | Capacity: 2800
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 2800 | Onboard: 69
# 🕐 Time: 13:12 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -94.48 | Onboard: 65 | Alighted: 58
# 📊 Excess Space: 2835 | Capacity: 2900
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 2900 | Onboard: 65
# 🕐 Time: 13:17 | Direction: SB
# 🎲 Random Agent chose: 1
# ✅ Reward: -475.86 | Onboard: 76 | Alighted: 29
# 📊 Excess Space: 2874 | Capacity: 2950
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 2950 | Onboard: 76
# 🕐 Time: 13:22 | Direction: SB
# 🎲 Random Agent chose: 0
# ✅ Reward: -1985.78 | Onboard: 0 | Alighted: 24
# 📊 Excess Space: 3050 | Capacity: 3050
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 3050 | Onboard: 0
# 🕐 Time: 13:27 | Direction: NB
# 🎲 Random Agent chose: 1
# ✅ Reward: -29.64 | Onboard: 45 | Alighted: 0
# 📊 Excess Space: 3055 | Capacity: 3100
#
#
# ==================================================
# 🏁 GAME OVER - FINAL STATISTICS
# ==================================================
# 📊 Raw Score: -8741.21
# ⭐ Normalized Score: 1/100
# 👥 Total Passengers Carried: 3448
# 🚪 Total Passengers Alighted: 2794
# 📦 Average Excess Space: 1404.4
# 📈 Peak Capacity Inefficiency: 3055
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 300.0
# ==================================================

# %%
# WORST CASE TEST - INEFFICIENT OPERATIONS

def test_worst_case_fixed():
    print("🚆 WORST CASE TEST - Inefficient Operations 🚆")
    print("=" * 60)
    
    # Create environment with fixed seed for reproducibility
    env = TrainGameEnv(initial_capacity=100, seed=42)
    
    # Store original final_score method
    original_final_score = env.final_score
    
    # Define fixed final_score method
    def fixed_final_score():
        distance_bonus = env.station_visits * 20  # Reduced from 50
        effective_score = env.raw_score + distance_bonus
        # More realistic normalization
        S_min = -100 * env.station_visits  # More negative minimum
        S_max = 150 * env.station_visits   # Lower maximum
        normalized = round(1 + ((effective_score - S_min) / (S_max - S_min)) * 99)
        return max(1, min(100, normalized)), effective_score
    
    # Replace the method
    env.final_score = fixed_final_score
    
    # Force worst-case conditions
    env.sim_minutes = 10 * 60  # 10:00 AM - moderate traffic
    env.capacity = 500  # Start with oversized capacity
    
    # Track metrics
    total_alighted = 0
    peak_excess_space = 0
    total_excess_space = 0
    station_count = 0
    
    # WORST-CASE ACTIONS: Always expand capacity even when empty
    worst_case_actions = [0, 1] * 25  # Alternate between Dagdag and Lapad
    
    for i, action in enumerate(worst_case_actions):
        if i >= 50:
            break
            
        draw_train(env)
        current_hour = env.sim_minutes // 60
        current_minute = env.sim_minutes % 60
        direction = "NB" if env.direction == 1 else "SB"
        print(f"🕐 Time: {current_hour:02d}:{current_minute:02d} | Direction: {direction}")
        print(f"🎲 WORST-CASE Action: {action} (Always expanding)")
        
        previous_onboard = env.passengers_onboard
        state, reward, done, info = env.step(action)
        
        alighted = info.get('alighted', 0)
        total_alighted += alighted
        
        excess_space = max(0, env.capacity - env.passengers_onboard)
        total_excess_space += excess_space
        peak_excess_space = max(peak_excess_space, excess_space)
        station_count += 1
        
        print(f"✅ Reward: {reward:.2f} | Onboard: {env.passengers_onboard} | Alighted: {alighted}")
        print(f"📊 Excess Space: {excess_space} | Capacity: {env.capacity}")
        print(f"💸 Config Cost: {env.total_config_cost:.1f}")
        print()
        
        time.sleep(0.05)

        if done:
            break

    final_norm, final_raw = env.final_score()
    average_excess_space = total_excess_space / station_count if station_count > 0 else 0
    
    print("\n" + "="*60)
    print("🏁 WORST CASE RESULTS - INEFFICIENT OPERATIONS")
    print("="*60)
    print(f"📊 Raw Score: {final_raw:.2f}")
    print(f"⭐ Normalized Score: {final_norm}/100")
    print(f"👥 Total Passengers Carried: {env.total_boarded}")
    print(f"🚪 Total Passengers Alighted: {total_alighted}")
    print(f"📦 Average Excess Space: {average_excess_space:.1f}")
    print(f"📈 Peak Capacity Inefficiency: {peak_excess_space}")
    print(f"🛑 Stations Visited: {env.station_visits}")
    print(f"⏱️  Total Steps: {env.steps}")
    print(f"💰 Total Configuration Cost: {env.total_config_cost:.1f}")
    print(f"🔧 Capacity Actions: {len(worst_case_actions)}")
    print("="*60)

# Run worst case test
test_worst_case_fixed()
# Out:
# 🚆 WORST CASE TEST - Inefficient Operations 🚆
# ============================================================
#
# 🚉------------
# 🚂
# 📍 Recto | Cap: 500 | Onboard: 0
# 🕐 Time: 10:00 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: 45.79 | Onboard: 43 | Alighted: 0
# 📊 Excess Space: 557 | Capacity: 600
# 💸 Config Cost: 10.0
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 600 | Onboard: 43
# 🕐 Time: 10:05 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -17.32 | Onboard: 47 | Alighted: 15
# 📊 Excess Space: 603 | Capacity: 650
# 💸 Config Cost: 15.0
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 650 | Onboard: 47
# 🕐 Time: 10:10 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -129.55 | Onboard: 94 | Alighted: 6
# 📊 Excess Space: 656 | Capacity: 750
# 💸 Config Cost: 25.0
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 750 | Onboard: 94
# 🕐 Time: 10:15 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: 0.92 | Onboard: 40 | Alighted: 69
# 📊 Excess Space: 760 | Capacity: 800
# 💸 Config Cost: 30.0
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 800 | Onboard: 40
# 🕐 Time: 10:20 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -281.39 | Onboard: 47 | Alighted: 2
# 📊 Excess Space: 853 | Capacity: 900
# 💸 Config Cost: 40.0
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 900 | Onboard: 47
# 🕐 Time: 10:25 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -92.33 | Onboard: 75 | Alighted: 14
# 📊 Excess Space: 875 | Capacity: 950
# 💸 Config Cost: 45.0
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 950 | Onboard: 75
# 🕐 Time: 10:30 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -0.68 | Onboard: 26 | Alighted: 71
# 📊 Excess Space: 1024 | Capacity: 1050
# 💸 Config Cost: 55.0
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 1050 | Onboard: 26
# 🕐 Time: 10:35 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: 99.03 | Onboard: 92 | Alighted: 22
# 📊 Excess Space: 1008 | Capacity: 1100
# 💸 Config Cost: 60.0
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 1100 | Onboard: 92
# 🕐 Time: 10:40 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: 17.51 | Onboard: 73 | Alighted: 57
# 📊 Excess Space: 1127 | Capacity: 1200
# 💸 Config Cost: 70.0
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 1200 | Onboard: 73
# 🕐 Time: 10:45 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -369.37 | Onboard: 132 | Alighted: 0
# 📊 Excess Space: 1118 | Capacity: 1250
# 💸 Config Cost: 75.0
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 1250 | Onboard: 132
# 🕐 Time: 10:50 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -10.82 | Onboard: 49 | Alighted: 108
# 📊 Excess Space: 1301 | Capacity: 1350
# 💸 Config Cost: 85.0
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 1350 | Onboard: 49
# 🕐 Time: 10:55 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -218.10 | Onboard: 83 | Alighted: 13
# 📊 Excess Space: 1317 | Capacity: 1400
# 💸 Config Cost: 90.0
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 1400 | Onboard: 83
# 🕐 Time: 11:00 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -407.43 | Onboard: 0 | Alighted: 11
# 📊 Excess Space: 1500 | Capacity: 1500
# 💸 Config Cost: 100.0
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 1500 | Onboard: 0
# 🕐 Time: 11:05 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -8.31 | Onboard: 26 | Alighted: 0
# 📊 Excess Space: 1524 | Capacity: 1550
# 💸 Config Cost: 105.0
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 1550 | Onboard: 26
# 🕐 Time: 11:10 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -31.13 | Onboard: 119 | Alighted: 11
# 📊 Excess Space: 1531 | Capacity: 1650
# 💸 Config Cost: 115.0
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 1650 | Onboard: 119
# 🕐 Time: 11:15 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -74.78 | Onboard: 153 | Alighted: 44
# 📊 Excess Space: 1547 | Capacity: 1700
# 💸 Config Cost: 120.0
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 1700 | Onboard: 153
# 🕐 Time: 11:20 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -60.25 | Onboard: 185 | Alighted: 67
# 📊 Excess Space: 1615 | Capacity: 1800
# 💸 Config Cost: 130.0
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 1800 | Onboard: 185
# 🕐 Time: 11:25 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -438.71 | Onboard: 390 | Alighted: 11
# 📊 Excess Space: 1460 | Capacity: 1850
# 💸 Config Cost: 135.0
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 1850 | Onboard: 390
# 🕐 Time: 11:30 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: 28.38 | Onboard: 227 | Alighted: 235
# 📊 Excess Space: 1723 | Capacity: 1950
# 💸 Config Cost: 145.0
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 1950 | Onboard: 227
# 🕐 Time: 11:35 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -764.04 | Onboard: 308 | Alighted: 31
# 📊 Excess Space: 1692 | Capacity: 2000
# 💸 Config Cost: 150.0
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 2000 | Onboard: 308
# 🕐 Time: 11:40 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -59.01 | Onboard: 139 | Alighted: 193
# 📊 Excess Space: 1961 | Capacity: 2100
# 💸 Config Cost: 160.0
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 2100 | Onboard: 139
# 🕐 Time: 11:45 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: 57.84 | Onboard: 167 | Alighted: 75
# 📊 Excess Space: 1983 | Capacity: 2150
# 💸 Config Cost: 165.0
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 2150 | Onboard: 167
# 🕐 Time: 11:50 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: 10.23 | Onboard: 87 | Alighted: 160
# 📊 Excess Space: 2163 | Capacity: 2250
# 💸 Config Cost: 175.0
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 2250 | Onboard: 87
# 🕐 Time: 11:55 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: 0.91 | Onboard: 116 | Alighted: 46
# 📊 Excess Space: 2184 | Capacity: 2300
# 💸 Config Cost: 180.0
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 2300 | Onboard: 116
# 🕐 Time: 12:00 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -1053.07 | Onboard: 0 | Alighted: 24
# 📊 Excess Space: 2400 | Capacity: 2400
# 💸 Config Cost: 190.0
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 2400 | Onboard: 0
# 🕐 Time: 12:05 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -41.13 | Onboard: 23 | Alighted: 0
# 📊 Excess Space: 2427 | Capacity: 2450
# 💸 Config Cost: 195.0
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 2450 | Onboard: 23
# 🕐 Time: 12:10 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -1476.17 | Onboard: 107 | Alighted: 1
# 📊 Excess Space: 2443 | Capacity: 2550
# 💸 Config Cost: 205.0
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 2550 | Onboard: 107
# 🕐 Time: 12:15 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -662.41 | Onboard: 175 | Alighted: 29
# 📊 Excess Space: 2425 | Capacity: 2600
# 💸 Config Cost: 210.0
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 2600 | Onboard: 175
# 🕐 Time: 12:20 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -405.07 | Onboard: 126 | Alighted: 74
# 📊 Excess Space: 2574 | Capacity: 2700
# 💸 Config Cost: 220.0
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 2700 | Onboard: 126
# 🕐 Time: 12:25 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -96.87 | Onboard: 57 | Alighted: 109
# 📊 Excess Space: 2693 | Capacity: 2750
# 💸 Config Cost: 225.0
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 2750 | Onboard: 57
# 🕐 Time: 12:30 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -130.86 | Onboard: 28 | Alighted: 55
# 📊 Excess Space: 2822 | Capacity: 2850
# 💸 Config Cost: 235.0
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 2850 | Onboard: 28
# 🕐 Time: 12:35 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -813.79 | Onboard: 140 | Alighted: 12
# 📊 Excess Space: 2760 | Capacity: 2900
# 💸 Config Cost: 240.0
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 2900 | Onboard: 140
# 🕐 Time: 12:40 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -56.63 | Onboard: 107 | Alighted: 116
# 📊 Excess Space: 2893 | Capacity: 3000
# 💸 Config Cost: 250.0
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 3000 | Onboard: 107
# 🕐 Time: 12:45 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -106.39 | Onboard: 56 | Alighted: 106
# 📊 Excess Space: 2994 | Capacity: 3050
# 💸 Config Cost: 255.0
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 3050 | Onboard: 56
# 🕐 Time: 12:50 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -2274.54 | Onboard: 101 | Alighted: 10
# 📊 Excess Space: 3049 | Capacity: 3150
# 💸 Config Cost: 265.0
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 3150 | Onboard: 101
# 🕐 Time: 12:55 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -551.58 | Onboard: 94 | Alighted: 45
# 📊 Excess Space: 3106 | Capacity: 3200
# 💸 Config Cost: 270.0
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 3200 | Onboard: 94
# 🕐 Time: 13:00 | Direction: NB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -29.79 | Onboard: 0 | Alighted: 85
# 📊 Excess Space: 3300 | Capacity: 3300
# 💸 Config Cost: 280.0
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 3300 | Onboard: 0
# 🕐 Time: 13:05 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: 32.58 | Onboard: 90 | Alighted: 0
# 📊 Excess Space: 3260 | Capacity: 3350
# 💸 Config Cost: 285.0
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 3350 | Onboard: 90
# 🕐 Time: 13:10 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -107.44 | Onboard: 88 | Alighted: 87
# 📊 Excess Space: 3362 | Capacity: 3450
# 💸 Config Cost: 295.0
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 3450 | Onboard: 88
# 🕐 Time: 13:15 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -2692.75 | Onboard: 159 | Alighted: 9
# 📊 Excess Space: 3341 | Capacity: 3500
# 💸 Config Cost: 300.0
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 3500 | Onboard: 159
# 🕐 Time: 13:20 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -1361.14 | Onboard: 189 | Alighted: 43
# 📊 Excess Space: 3411 | Capacity: 3600
# 💸 Config Cost: 310.0
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 3600 | Onboard: 189
# 🕐 Time: 13:25 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -80.24 | Onboard: 121 | Alighted: 186
# 📊 Excess Space: 3529 | Capacity: 3650
# 💸 Config Cost: 315.0
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 3650 | Onboard: 121
# 🕐 Time: 13:30 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -3097.52 | Onboard: 166 | Alighted: 20
# 📊 Excess Space: 3584 | Capacity: 3750
# 💸 Config Cost: 325.0
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 3750 | Onboard: 166
# 🕐 Time: 13:35 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -210.30 | Onboard: 114 | Alighted: 97
# 📊 Excess Space: 3686 | Capacity: 3800
# 💸 Config Cost: 330.0
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 3800 | Onboard: 114
# 🕐 Time: 13:40 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -156.82 | Onboard: 123 | Alighted: 81
# 📊 Excess Space: 3777 | Capacity: 3900
# 💸 Config Cost: 340.0
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 3900 | Onboard: 123
# 🕐 Time: 13:45 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -240.35 | Onboard: 92 | Alighted: 71
# 📊 Excess Space: 3858 | Capacity: 3950
# 💸 Config Cost: 345.0
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 3950 | Onboard: 92
# 🕐 Time: 13:50 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -243.54 | Onboard: 55 | Alighted: 87
# 📊 Excess Space: 3995 | Capacity: 4050
# 💸 Config Cost: 355.0
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 4050 | Onboard: 55
# 🕐 Time: 13:55 | Direction: SB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -172.80 | Onboard: 101 | Alighted: 53
# 📊 Excess Space: 3999 | Capacity: 4100
# 💸 Config Cost: 360.0
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 4100 | Onboard: 101
# 🕐 Time: 14:00 | Direction: SB
# 🎲 WORST-CASE Action: 0 (Always expanding)
# ✅ Reward: -283.64 | Onboard: 0 | Alighted: 99
# 📊 Excess Space: 4200 | Capacity: 4200
# 💸 Config Cost: 370.0
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 4200 | Onboard: 0
# 🕐 Time: 14:05 | Direction: NB
# 🎲 WORST-CASE Action: 1 (Always expanding)
# ✅ Reward: -114.84 | Onboard: 13 | Alighted: 0
# 📊 Excess Space: 4237 | Capacity: 4250
# 💸 Config Cost: 375.0
#
#
# ============================================================
# 🏁 WORST CASE RESULTS - INEFFICIENT OPERATIONS
# ============================================================
# 📊 Raw Score: -18804.73
# ⭐ Normalized Score: 1/100
# 👥 Total Passengers Carried: 3465
# 🚪 Total Passengers Alighted: 2760
# 📦 Average Excess Space: 2324.1
# 📈 Peak Capacity Inefficiency: 4237
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 375.0
# 🔧 Capacity Actions: 50
# ============================================================

# %%
# BEST CASE TEST - EFFICIENT OPERATIONS

def test_best_case_fixed():
    print("🚆 BEST CASE TEST - Efficient Operations 🚆")
    print("=" * 60)
    
    # Create environment with fixed seed for reproducibility
    env = TrainGameEnv(initial_capacity=100, seed=42)
    
    # Store original final_score method
    original_final_score = env.final_score
    
    # Define fixed final_score method
    def fixed_final_score():
        distance_bonus = env.station_visits * 20  # Reduced from 50
        effective_score = env.raw_score + distance_bonus
        # More realistic normalization
        S_min = -100 * env.station_visits  # More negative minimum
        S_max = 150 * env.station_visits   # Lower maximum
        normalized = round(1 + ((effective_score - S_min) / (S_max - S_min)) * 99)
        return max(1, min(100, normalized)), effective_score
    
    # Replace the method
    env.final_score = fixed_final_score
    
    # Force best-case conditions
    env.sim_minutes = 8 * 60  # 8:00 AM - rush hour
    env.capacity = 150  # Start with reasonable capacity
    
    # Track metrics
    total_alighted = 0
    peak_excess_space = 0
    total_excess_space = 0
    station_count = 0
    
    # BEST-CASE ACTIONS: Strategic capacity expansion only when needed
    best_case_actions = [
        2, 2, 2, 2, 2, 2, 2, 2, 2, 2,  # No expansion initially
        1, 2, 2, 2, 2,  # Small expansion when actually needed
        1, 2, 2, 2, 2,
        0, 2, 2, 2, 2,  # Medium expansion during actual peak
        1, 2, 2, 2, 2,
        2, 2, 2, 2, 2, 2, 2, 2, 2, 2,  # Minimal expansion
        1, 2, 2, 2, 2
    ]
    
    for i, action in enumerate(best_case_actions):
        if i >= 50:
            break
            
        draw_train(env)
        current_hour = env.sim_minutes // 60
        current_minute = env.sim_minutes % 60
        direction = "NB" if env.direction == 1 else "SB"
        print(f"🕐 Time: {current_hour:02d}:{current_minute:02d} | Direction: {direction}")
        
        action_names = {0: "Dagdag", 1: "Lapad", 2: "None"}
        print(f"🎯 STRATEGIC Action: {action} ({action_names[action]})")
        
        previous_onboard = env.passengers_onboard
        state, reward, done, info = env.step(action)
        
        alighted = info.get('alighted', 0)
        total_alighted += alighted
        
        excess_space = max(0, env.capacity - env.passengers_onboard)
        total_excess_space += excess_space
        peak_excess_space = max(peak_excess_space, excess_space)
        station_count += 1
        
        efficiency_ratio = info.get('efficiency_ratio', 0)
        penalty_unused = info.get('penalty_unused', 0)
        
        print(f"✅ Reward: {reward:.2f} | Onboard: {env.passengers_onboard} | Alighted: {alighted}")
        print(f"📊 Excess Space: {excess_space} | Capacity: {env.capacity}")
        print(f"📈 Efficiency Ratio: {efficiency_ratio:.2f} | Penalty: {penalty_unused:.2f}")
        print()
        
        time.sleep(0.05)

        if done:
            break

    final_norm, final_raw = env.final_score()
    average_excess_space = total_excess_space / station_count if station_count > 0 else 0
    
    print("\n" + "="*60)
    print("🏁 BEST CASE RESULTS - EFFICIENT OPERATIONS")
    print("="*60)
    print(f"📊 Raw Score: {final_raw:.2f}")
    print(f"⭐ Normalized Score: {final_norm}/100")
    print(f"👥 Total Passengers Carried: {env.total_boarded}")
    print(f"🚪 Total Passengers Alighted: {total_alighted}")
    print(f"📦 Average Excess Space: {average_excess_space:.1f}")
    print(f"📈 Peak Capacity Inefficiency: {peak_excess_space}")
    print(f"🛑 Stations Visited: {env.station_visits}")
    print(f"⏱️  Total Steps: {env.steps}")
    print(f"💰 Total Configuration Cost: {env.total_config_cost:.1f}")
    print(f"🔧 Capacity Actions: {sum(1 for a in best_case_actions if a != 2)}")
    print("="*60)

# Run best case test
test_best_case_fixed()
# Out:
# 🚆 BEST CASE TEST - Efficient Operations 🚆
# ============================================================
#
# 🚉------------
# 🚂
# 📍 Recto | Cap: 150 | Onboard: 0
# 🕐 Time: 08:00 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 120.96 | Onboard: 82 | Alighted: 0
# 📊 Excess Space: 68 | Capacity: 150
# 📈 Efficiency Ratio: 0.00 | Penalty: 2.04
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 150 | Onboard: 82
# 🕐 Time: 08:05 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 69.15 | Onboard: 95 | Alighted: 35
# 📊 Excess Space: 55 | Capacity: 150
# 📈 Efficiency Ratio: 0.43 | Penalty: 2.85
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 150 | Onboard: 95
# 🕐 Time: 08:10 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 45.92 | Onboard: 101 | Alighted: 28
# 📊 Excess Space: 49 | Capacity: 150
# 📈 Efficiency Ratio: 0.29 | Penalty: 5.08
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 150 | Onboard: 101
# 🕐 Time: 08:15 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 43.04 | Onboard: 37 | Alighted: 94
# 📊 Excess Space: 113 | Capacity: 150
# 📈 Efficiency Ratio: 0.93 | Penalty: 1.96
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 150 | Onboard: 37
# 🕐 Time: 08:20 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 41.46 | Onboard: 32 | Alighted: 34
# 📊 Excess Space: 118 | Capacity: 150
# 📈 Efficiency Ratio: 0.92 | Penalty: 2.04
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 150 | Onboard: 32
# 🕐 Time: 08:25 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 32.38 | Onboard: 28 | Alighted: 27
# 📊 Excess Space: 122 | Capacity: 150
# 📈 Efficiency Ratio: 0.84 | Penalty: 2.12
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 150 | Onboard: 28
# 🕐 Time: 08:30 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 24.13 | Onboard: 57 | Alighted: 0
# 📊 Excess Space: 93 | Capacity: 150
# 📈 Efficiency Ratio: 0.00 | Penalty: 19.37
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 150 | Onboard: 57
# 🕐 Time: 08:35 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 159.00 | Onboard: 150 | Alighted: 13
# 📊 Excess Space: 0 | Capacity: 150
# 📈 Efficiency Ratio: 0.23 | Penalty: 0.00
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 150 | Onboard: 150
# 🕐 Time: 08:40 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 137.36 | Onboard: 113 | Alighted: 129
# 📊 Excess Space: 37 | Capacity: 150
# 📈 Efficiency Ratio: 0.86 | Penalty: 0.64
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 150 | Onboard: 113
# 🕐 Time: 08:45 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 60.00 | Onboard: 150 | Alighted: 3
# 📊 Excess Space: 0 | Capacity: 150
# 📈 Efficiency Ratio: 0.03 | Penalty: 0.00
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 150 | Onboard: 150
# 🕐 Time: 08:50 | Direction: NB
# 🎯 STRATEGIC Action: 1 (Lapad)
# ✅ Reward: 149.00 | Onboard: 200 | Alighted: 50
# 📊 Excess Space: 0 | Capacity: 200
# 📈 Efficiency Ratio: 0.33 | Penalty: 0.00
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 200 | Onboard: 200
# 🕐 Time: 08:55 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 154.87 | Onboard: 138 | Alighted: 166
# 📊 Excess Space: 62 | Capacity: 200
# 📈 Efficiency Ratio: 0.83 | Penalty: 1.13
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 200 | Onboard: 138
# 🕐 Time: 09:00 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 79.86 | Onboard: 0 | Alighted: 107
# 📊 Excess Space: 200 | Capacity: 200
# 📈 Efficiency Ratio: 0.78 | Penalty: 2.64
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 200 | Onboard: 0
# 🕐 Time: 09:05 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 35.24 | Onboard: 27 | Alighted: 0
# 📊 Excess Space: 173 | Capacity: 200
# 📈 Efficiency Ratio: 0.00 | Penalty: 5.26
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 200 | Onboard: 27
# 🕐 Time: 09:10 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 63.53 | Onboard: 86 | Alighted: 0
# 📊 Excess Space: 114 | Capacity: 200
# 📈 Efficiency Ratio: 0.00 | Penalty: 24.97
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 200 | Onboard: 86
# 🕐 Time: 09:15 | Direction: SB
# 🎯 STRATEGIC Action: 1 (Lapad)
# ✅ Reward: 32.83 | Onboard: 57 | Alighted: 54
# 📊 Excess Space: 193 | Capacity: 250
# 📈 Efficiency Ratio: 0.63 | Penalty: 3.67
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 250 | Onboard: 57
# 🕐 Time: 09:20 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 52.33 | Onboard: 91 | Alighted: 13
# 📊 Excess Space: 159 | Capacity: 250
# 📈 Efficiency Ratio: 0.23 | Penalty: 18.17
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 250 | Onboard: 91
# 🕐 Time: 09:25 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 85.58 | Onboard: 152 | Alighted: 11
# 📊 Excess Space: 98 | Capacity: 250
# 📈 Efficiency Ratio: 0.12 | Penalty: 22.42
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 250 | Onboard: 152
# 🕐 Time: 09:30 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 55.69 | Onboard: 103 | Alighted: 88
# 📊 Excess Space: 147 | Capacity: 250
# 📈 Efficiency Ratio: 0.58 | Penalty: 2.81
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 250 | Onboard: 103
# 🕐 Time: 09:35 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 63.72 | Onboard: 155 | Alighted: 5
# 📊 Excess Space: 95 | Capacity: 250
# 📈 Efficiency Ratio: 0.05 | Penalty: 21.78
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 250 | Onboard: 155
# 🕐 Time: 09:40 | Direction: SB
# 🎯 STRATEGIC Action: 0 (Dagdag)
# ✅ Reward: 39.86 | Onboard: 180 | Alighted: 31
# 📊 Excess Space: 170 | Capacity: 350
# 📈 Efficiency Ratio: 0.20 | Penalty: 42.14
#
#
# ---🚉---------
#    🚋
# 📍 V. Mapa | Cap: 350 | Onboard: 180
# 🕐 Time: 09:45 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 37.67 | Onboard: 68 | Alighted: 141
# 📊 Excess Space: 282 | Capacity: 350
# 📈 Efficiency Ratio: 0.78 | Penalty: 5.83
#
#
# --🚉----------
#   🚋
# 📍 Pureza | Cap: 350 | Onboard: 68
# 🕐 Time: 09:50 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 51.00 | Onboard: 60 | Alighted: 46
# 📊 Excess Space: 290 | Capacity: 350
# 📈 Efficiency Ratio: 0.68 | Penalty: 6.00
#
#
# -🚉-----------
#  🚋
# 📍 Legarda | Cap: 350 | Onboard: 60
# 🕐 Time: 09:55 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: -52.10 | Onboard: 68 | Alighted: 4
# 📊 Excess Space: 282 | Capacity: 350
# 📈 Efficiency Ratio: 0.07 | Penalty: 70.10
#
#
# 🚉------------
# 🚋
# 📍 Recto | Cap: 350 | Onboard: 68
# 🕐 Time: 10:00 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 70.30 | Onboard: 0 | Alighted: 37
# 📊 Excess Space: 350 | Capacity: 350
# 📈 Efficiency Ratio: 0.54 | Penalty: 6.20
#
#
# -🚉-----------
#  🚂
# 📍 Legarda | Cap: 350 | Onboard: 0
# 🕐 Time: 10:05 | Direction: NB
# 🎯 STRATEGIC Action: 1 (Lapad)
# ✅ Reward: 67.83 | Onboard: 53 | Alighted: 0
# 📊 Excess Space: 347 | Capacity: 400
# 📈 Efficiency Ratio: 0.00 | Penalty: 10.67
#
#
# --🚉----------
#   🚂
# 📍 Pureza | Cap: 400 | Onboard: 53
# 🕐 Time: 10:10 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 39.06 | Onboard: 76 | Alighted: 17
# 📊 Excess Space: 324 | Capacity: 400
# 📈 Efficiency Ratio: 0.32 | Penalty: 20.94
#
#
# ---🚉---------
#    🚂
# 📍 V. Mapa | Cap: 400 | Onboard: 76
# 🕐 Time: 10:15 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 16.37 | Onboard: 46 | Alighted: 46
# 📊 Excess Space: 354 | Capacity: 400
# 📈 Efficiency Ratio: 0.61 | Penalty: 7.63
#
#
# ----🚉--------
#     🚂
# 📍 J. Ruiz | Cap: 400 | Onboard: 46
# 🕐 Time: 10:20 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 22.53 | Onboard: 76 | Alighted: 13
# 📊 Excess Space: 324 | Capacity: 400
# 📈 Efficiency Ratio: 0.28 | Penalty: 41.97
#
#
# -----🚉-------
#      🚂
# 📍 Gilmore | Cap: 400 | Onboard: 76
# 🕐 Time: 10:25 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: -0.14 | Onboard: 116 | Alighted: 9
# 📊 Excess Space: 284 | Capacity: 400
# 📈 Efficiency Ratio: 0.12 | Penalty: 73.64
#
#
# ------🚉------
#       🚂
# 📍 Betty Go | Cap: 400 | Onboard: 116
# 🕐 Time: 10:30 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 62.38 | Onboard: 94 | Alighted: 68
# 📊 Excess Space: 306 | Capacity: 400
# 📈 Efficiency Ratio: 0.59 | Penalty: 6.62
#
#
# -------🚉-----
#        🚂
# 📍 Cubao | Cap: 400 | Onboard: 94
# 🕐 Time: 10:35 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 103.18 | Onboard: 108 | Alighted: 59
# 📊 Excess Space: 292 | Capacity: 400
# 📈 Efficiency Ratio: 0.63 | Penalty: 6.32
#
#
# --------🚉----
#         🚂
# 📍 Anonas | Cap: 400 | Onboard: 108
# 🕐 Time: 10:40 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 77.13 | Onboard: 83 | Alighted: 81
# 📊 Excess Space: 317 | Capacity: 400
# 📈 Efficiency Ratio: 0.75 | Penalty: 6.87
#
#
# ---------🚉---
#          🚂
# 📍 Katipunan | Cap: 400 | Onboard: 83
# 🕐 Time: 10:45 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 91.14 | Onboard: 107 | Alighted: 41
# 📊 Excess Space: 293 | Capacity: 400
# 📈 Efficiency Ratio: 0.49 | Penalty: 6.36
#
#
# ----------🚉--
#           🚂
# 📍 Santolan | Cap: 400 | Onboard: 107
# 🕐 Time: 10:50 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: -34.16 | Onboard: 125 | Alighted: 7
# 📊 Excess Space: 275 | Capacity: 400
# 📈 Efficiency Ratio: 0.07 | Penalty: 71.66
#
#
# -----------🚉-
#            🚂
# 📍 Marikina | Cap: 400 | Onboard: 125
# 🕐 Time: 10:55 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 29.83 | Onboard: 47 | Alighted: 103
# 📊 Excess Space: 353 | Capacity: 400
# 📈 Efficiency Ratio: 0.82 | Penalty: 7.67
#
#
# ------------🚉
#             🚂
# 📍 Antipolo | Cap: 400 | Onboard: 47
# 🕐 Time: 11:00 | Direction: NB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 91.05 | Onboard: 0 | Alighted: 4
# 📊 Excess Space: 400 | Capacity: 400
# 📈 Efficiency Ratio: 0.09 | Penalty: 75.45
#
#
# -----------🚉-
#            🚋
# 📍 Marikina | Cap: 400 | Onboard: 0
# 🕐 Time: 11:05 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 160.57 | Onboard: 113 | Alighted: 0
# 📊 Excess Space: 287 | Capacity: 400
# 📈 Efficiency Ratio: 0.00 | Penalty: 8.93
#
#
# ----------🚉--
#           🚋
# 📍 Santolan | Cap: 400 | Onboard: 113
# 🕐 Time: 11:10 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 159.57 | Onboard: 151 | Alighted: 72
# 📊 Excess Space: 249 | Capacity: 400
# 📈 Efficiency Ratio: 0.64 | Penalty: 5.43
#
#
# ---------🚉---
#          🚋
# 📍 Katipunan | Cap: 400 | Onboard: 151
# 🕐 Time: 11:15 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 50.65 | Onboard: 109 | Alighted: 80
# 📊 Excess Space: 291 | Capacity: 400
# 📈 Efficiency Ratio: 0.53 | Penalty: 6.35
#
#
# --------🚉----
#         🚋
# 📍 Anonas | Cap: 400 | Onboard: 109
# 🕐 Time: 11:20 | Direction: SB
# 🎯 STRATEGIC Action: 1 (Lapad)
# ✅ Reward: 92.95 | Onboard: 94 | Alighted: 83
# 📊 Excess Space: 356 | Capacity: 450
# 📈 Efficiency Ratio: 0.76 | Penalty: 8.05
#
#
# -------🚉-----
#        🚋
# 📍 Cubao | Cap: 450 | Onboard: 94
# 🕐 Time: 11:25 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 290.71 | Onboard: 247 | Alighted: 50
# 📊 Excess Space: 203 | Capacity: 450
# 📈 Efficiency Ratio: 0.53 | Penalty: 13.79
#
#
# ------🚉------
#       🚋
# 📍 Betty Go | Cap: 450 | Onboard: 247
# 🕐 Time: 11:30 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 28.42 | Onboard: 162 | Alighted: 117
# 📊 Excess Space: 288 | Capacity: 450
# 📈 Efficiency Ratio: 0.47 | Penalty: 19.58
#
#
# -----🚉-------
#      🚋
# 📍 Gilmore | Cap: 450 | Onboard: 162
# 🕐 Time: 11:35 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 22.88 | Onboard: 125 | Alighted: 67
# 📊 Excess Space: 325 | Capacity: 450
# 📈 Efficiency Ratio: 0.41 | Penalty: 22.12
#
#
# ----🚉--------
#     🚋
# 📍 J. Ruiz | Cap: 450 | Onboard: 125
# 🕐 Time: 11:40 | Direction: SB
# 🎯 STRATEGIC Action: 2 (None)
# ✅ Reward: 71.38 | Onboard: 189 | Alighted: 31
# 📊 Excess Space: 261 | Capacity: 450
# 📈 Efficiency Ratio: 0.25 | Penalty: 71.12
#
#
# ============================================================
# 🏁 BEST CASE RESULTS - EFFICIENT OPERATIONS
# ============================================================
# 📊 Raw Score: 3942.11
# ⭐ Normalized Score: 75/100
# 👥 Total Passengers Carried: 2575
# 🚪 Total Passengers Alighted: 2064
# 📦 Average Excess Space: 208.9
# 📈 Peak Capacity Inefficiency: 400
# 🛑 Stations Visited: 45
# ⏱️  Total Steps: 45
# 💰 Total Configuration Cost: 30.0
# 🔧 Capacity Actions: 5
# ============================================================

# %% [markdown]
# SCORES FOR V1
#
# ============================================================
# 🏁 WORST CASE RESULTS - INEFFICIENT OPERATIONS
# ============================================================
# 📊 Raw Score: 6254.32
# ⭐ Normalized Score: 90/100
# 👥 Total Passengers Carried: 3465
# 🚪 Total Passengers Alighted: 2760
# 📦 Average Excess Space: 2324.1
# 📈 Peak Capacity Inefficiency: 4237
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 375.0
# 🔧 Capacity Actions: 50
# ============================================================
#
# ============================================================
# 🏁 BEST CASE RESULTS - EFFICIENT OPERATIONS
# ============================================================
# 📊 Raw Score: 5794.10
# ⭐ Normalized Score: 92/100
# 👥 Total Passengers Carried: 2575
# 🚪 Total Passengers Alighted: 2064
# 📦 Average Excess Space: 208.9
# 📈 Peak Capacity Inefficiency: 400
# 🛑 Stations Visited: 45
# ⏱️  Total Steps: 45
# 💰 Total Configuration Cost: 30.0
# 🔧 Capacity Actions: 5
# ============================================================
#
# ==================================================
# 🏁 RANDOMIZED - FINAL STATISTICS
# ==================================================
# 📊 Raw Score: 8480.41
# ⭐ Normalized Score: 88/100
# 👥 Total Passengers Carried: 3382
# 🚪 Total Passengers Alighted: 2767
# 📦 Average Excess Space: 1310.8
# 📈 Peak Capacity Inefficiency: 2650
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 255.0
# ==================================================
#
# ========================================================================================================================
# ========================================================================================================================
# ========================================================================================================================
#
# SCORES FOR V2
#
# ==================================================
# 🏁 RANDOM 1
# ==================================================
# 📊 Raw Score: -5645.36
# ⭐ Normalized Score: 1/100
# 👥 Total Passengers Carried: 3655
# 🚪 Total Passengers Alighted: 2724
# 📦 Average Excess Space: 1302.0
# 📈 Peak Capacity Inefficiency: 2677
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 260.0
# ==================================================
#
# ==================================================
# 🏁 RANDOM 2
# ==================================================
# 📊 Raw Score: -244.64
# ⭐ Normalized Score: 41/100
# 👥 Total Passengers Carried: 1623
# 🚪 Total Passengers Alighted: 1226
# 📦 Average Excess Space: 653.8
# 📈 Peak Capacity Inefficiency: 1288
# 🛑 Stations Visited: 30
# ⏱️  Total Steps: 30
# 💰 Total Configuration Cost: 130.0
# ==================================================
#
# ==================================================
# 🏁 RANDOM 3
# ==================================================
# 📊 Raw Score: -2036.69
# ⭐ Normalized Score: 23/100
# 👥 Total Passengers Carried: 3382
# 🚪 Total Passengers Alighted: 2767
# 📦 Average Excess Space: 1310.8
# 📈 Peak Capacity Inefficiency: 2650
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 255.0
# ==================================================
#
# ==================================================
# 🏁 RANDOM 4
# ==================================================
# 📊 Raw Score: -3942.13
# ⭐ Normalized Score: 2/100
# 👥 Total Passengers Carried: 4260
# 🚪 Total Passengers Alighted: 3271
# 📦 Average Excess Space: 1460.8
# 📈 Peak Capacity Inefficiency: 2990
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 290.0
# ==================================================
#
# ==================================================
# 🏁 RANDOM 5
# ==================================================
# 📊 Raw Score: -5180.73
# ⭐ Normalized Score: 1/100
# 👥 Total Passengers Carried: 4317
# 🚪 Total Passengers Alighted: 3408
# 📦 Average Excess Space: 1262.8
# 📈 Peak Capacity Inefficiency: 2687
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 260.0
# ==================================================
#
# ==================================================
# 🏁 RANDOM 5
# ==================================================
# 📊 Raw Score: -6805.76
# ⭐ Normalized Score: 1/100
# 👥 Total Passengers Carried: 3242
# 🚪 Total Passengers Alighted: 2411
# 📦 Average Excess Space: 1166.1
# 📈 Peak Capacity Inefficiency: 2300
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 225.0
# ==================================================
#
# ============================================================
# 🏁 WORST CASE RESULTS - INEFFICIENT OPERATIONS
# ============================================================
# 📊 Raw Score: -18804.73
# ⭐ Normalized Score: 1/100
# 👥 Total Passengers Carried: 3465
# 🚪 Total Passengers Alighted: 2760
# 📦 Average Excess Space: 2324.1
# 📈 Peak Capacity Inefficiency: 4237
# 🛑 Stations Visited: 50
# ⏱️  Total Steps: 50
# 💰 Total Configuration Cost: 375.0
# 🔧 Capacity Actions: 50
# ============================================================
#
# ============================================================
# 🏁 BEST CASE RESULTS - EFFICIENT OPERATIONS
# ============================================================
# 📊 Raw Score: 3942.11
# ⭐ Normalized Score: 75/100
# 👥 Total Passengers Carried: 2575
# 🚪 Total Passengers Alighted: 2064
# 📦 Average Excess Space: 208.9
# 📈 Peak Capacity Inefficiency: 400
# 🛑 Stations Visited: 45
# ⏱️  Total Steps: 45
# 💰 Total Configuration Cost: 30.0
# 🔧 Capacity Actions: 5
# ============================================================
